# %%
import sys
sys.path.append("../../..")

from src.dataset_tools.scrapers import BingScraper, BingFiltersSpec

# %%
QUERIES = [
    "apple",
    "banana",
]

# %%
scrapper = BingScraper(num_workers=4)

# %%
scrapper.scrape_many(
    queries=QUERIES,
    output_dir="../../../datasets/scrapped",
    filters=BingFiltersSpec(
        type='photo',
        size='medium',
    )
)
