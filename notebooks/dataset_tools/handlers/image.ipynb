# %%
import sys
sys.path.append("../../..")

from src.dataset_tools.handlers import YOLOImageHandler

# %%
manager = YOLOImageHandler(
    images_dir="../../../datasets/processed",
    recursive=True
)

# %%
manager.validate_images()
# Out:
# d:\My_Files\Projects\nn\ProdEye\.venv\lib\site-packages\PIL\TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# []
