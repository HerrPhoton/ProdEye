# %%
import sys
sys.path.append("../../..")

from src.dataset_tools.handlers import YOLOLabelHandler

# %%
manager = YOLOLabelHandler(
    labels_dir="../../../datasets/test",
    recursive=True,
)

# %%
manager.validate_labels(1)
# Out:
# []

# %%
renamed_labels = manager.rename_labels(
    new_name="fruit",
    start_idx=1,
    zero_padding=2
)

# %%
COUNT = 10

for old_lbl, new_lbl in renamed_labels[:COUNT]:
    print(f"{old_lbl} -> {new_lbl}")
# Out:
# ..\..\..\datasets\test\labels\apple_01.txt -> ..\..\..\datasets\test\labels\fruit_01.txt
# ..\..\..\datasets\test\labels\apple_02.txt -> ..\..\..\datasets\test\labels\fruit_02.txt
# ..\..\..\datasets\test\labels\apple_03.txt -> ..\..\..\datasets\test\labels\fruit_03.txt
# ..\..\..\datasets\test\labels\apple_04.txt -> ..\..\..\datasets\test\labels\fruit_04.txt
# ..\..\..\datasets\test\labels\apple_05.txt -> ..\..\..\datasets\test\labels\fruit_05.txt
# ..\..\..\datasets\test\labels\apple_06.txt -> ..\..\..\datasets\test\labels\fruit_06.txt
# ..\..\..\datasets\test\labels\apple_07.txt -> ..\..\..\datasets\test\labels\fruit_07.txt
# ..\..\..\datasets\test\labels\apple_08.txt -> ..\..\..\datasets\test\labels\fruit_08.txt
# ..\..\..\datasets\test\labels\apple_09.txt -> ..\..\..\datasets\test\labels\fruit_09.txt
# ..\..\..\datasets\test\labels\apple_10.txt -> ..\..\..\datasets\test\labels\fruit_10.txt
