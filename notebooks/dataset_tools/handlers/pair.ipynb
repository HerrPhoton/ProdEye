# %%
import sys
sys.path.append("../..")

from src.dataset_tools import YOLOPairHandler

# %%
manager = YOLOPairHandler(
    images_dir="../../datasets/test/images",
    labels_dir="../../datasets/test/labels"
)

# %%
manager.get_unlabeled_images()
# Out:
# ['..\\..\\datasets\\test\\images\\apple_0.jpg']

# %%
manager.create_empty_labels()
# Out:
# ['..\\..\\datasets\\test\\labels\\apple_0.txt']

# %%
manager = YOLOPairHandler.from_yaml("../../datasets/processed/v1/data.yaml")
