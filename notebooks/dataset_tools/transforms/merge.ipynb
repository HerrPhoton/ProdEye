# %%
import sys
sys.path.append("../../..")

from src.dataset_tools.transforms import DatasetMerger

# %%
merger = DatasetMerger([
    "../../../datasets/test1/data.yaml",
    "../../../datasets/test2/data.yaml",
])

# %%
merged_dataset = merger.merge("../../../datasets/merged_test", on_conflict="rename")
# Out:
# Объединение датасетов: 100%|██████████| 2242/2242 [00:04<00:00, 529.77it/s]
