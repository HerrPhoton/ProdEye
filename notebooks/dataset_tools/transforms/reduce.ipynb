# %%
import sys
sys.path.append("../../..")

from src.dataset_tools.transforms import DatasetReducer

# %%
reducer = DatasetReducer("../../../datasets/test")

# %%
reducer.reduce(
    split_sizes={"test": 1798},
    strategy="random"
)
# Out:
# {'test': ReductionResult(initial_count=1800, removed_count=2, final_count=1798, removed_files=[(WindowsPath('D:/My_Files/Projects/nn/ProdEye/datasets/test/images/pineapple_32.jpg'), WindowsPath('D:/My_Files/Projects/nn/ProdEye/datasets/test/labels/pineapple_32.txt')), (WindowsPath('D:/My_Files/Projects/nn/ProdEye/datasets/test/images/background_161.jpg'), WindowsPath('D:/My_Files/Projects/nn/ProdEye/datasets/test/labels/background_161.txt'))])}
