# %%
import sys
sys.path.append("../../..")

from src.dataset_tools.structures import Split

# %%
split = Split(
    name="test",
    images_dir="../../../datasets/test/images",
    labels_dir="../../../datasets/test/labels",
)

# %%
split.count_images()
# Out:
# 1833

# %%
split.count_labels()
# Out:
# 1833

# %%
split.count_samples()
# Out:
# 1833

# %%
split.exists()
# Out:
# True

# %%
COUNT = 10

images = [p for p in split.iter_images()][:COUNT]
labels = [p for p in split.iter_labels()][:COUNT]
samples = [p for p in split.iter_samples()][:COUNT]

# %%
for image_path in images:
    print(image_path)
# Out:
# ..\..\..\datasets\test\images\apple_0.jpg
# ..\..\..\datasets\test\images\apple_1.jpg
# ..\..\..\datasets\test\images\apple_10.jpg
# ..\..\..\datasets\test\images\apple_101.jpg
# ..\..\..\datasets\test\images\apple_103.jpg
# ..\..\..\datasets\test\images\apple_104.jpg
# ..\..\..\datasets\test\images\apple_105.jpg
# ..\..\..\datasets\test\images\apple_108.jpg
# ..\..\..\datasets\test\images\apple_109.jpg
# ..\..\..\datasets\test\images\apple_11.jpg

# %%
for label_path in labels:
    print(label_path)
# Out:
# ..\..\..\datasets\test\labels\apple_0.txt
# ..\..\..\datasets\test\labels\apple_1.txt
# ..\..\..\datasets\test\labels\apple_10.txt
# ..\..\..\datasets\test\labels\apple_101.txt
# ..\..\..\datasets\test\labels\apple_103.txt
# ..\..\..\datasets\test\labels\apple_104.txt
# ..\..\..\datasets\test\labels\apple_105.txt
# ..\..\..\datasets\test\labels\apple_108.txt
# ..\..\..\datasets\test\labels\apple_109.txt
# ..\..\..\datasets\test\labels\apple_11.txt

# %%
for sample in samples:
    print(sample)
# Out:
# (WindowsPath('../../../datasets/test/images/apple_0.jpg'), WindowsPath('../../../datasets/test/labels/apple_0.txt'))
# (WindowsPath('../../../datasets/test/images/apple_1.jpg'), WindowsPath('../../../datasets/test/labels/apple_1.txt'))
# (WindowsPath('../../../datasets/test/images/apple_10.jpg'), WindowsPath('../../../datasets/test/labels/apple_10.txt'))
# (WindowsPath('../../../datasets/test/images/apple_101.jpg'), WindowsPath('../../../datasets/test/labels/apple_101.txt'))
# (WindowsPath('../../../datasets/test/images/apple_103.jpg'), WindowsPath('../../../datasets/test/labels/apple_103.txt'))
# (WindowsPath('../../../datasets/test/images/apple_104.jpg'), WindowsPath('../../../datasets/test/labels/apple_104.txt'))
# (WindowsPath('../../../datasets/test/images/apple_105.jpg'), WindowsPath('../../../datasets/test/labels/apple_105.txt'))
# (WindowsPath('../../../datasets/test/images/apple_108.jpg'), WindowsPath('../../../datasets/test/labels/apple_108.txt'))
# ...
