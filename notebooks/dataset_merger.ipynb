# %%
import sys
sys.path.append('..')

from scripts.dataset_merger import YOLODatasetMerger

# %%
merger = YOLODatasetMerger(source_dir='../dataset/raw', output_dir='../dataset/processed/v1')
merger.merge()
# Out:
# 2024-11-29 15:48:26,303 - INFO - Начинаем слияние датасетов...
# Обработка датасетов:  74%|███████▍  | 23/31 [00:18<00:06,  1.28it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 merger = YOLODatasetMerger(source_dir='../dataset/raw', output_dir='../dataset/processed/v1')
# ----> 2 merger.merge()
#
# File d:\My_Files\NSU\4 Course\ProdEye\notebooks\..\scripts\dataset_merger.py:112, in YOLODatasetMerger.merge(self, use_threads)
#     110 if use_threads:
#     111     with ThreadPoolExecutor() as executor:
# --> 112         list(tqdm(
#     113             executor.map(lambda x: self._process_split(*x), tasks),
#     114             total=len(tasks),
#     115             desc="Обработка датасетов"
#     116         ))
#     117 else:
#     118     for task in tqdm(tasks, desc="Обработка датасетов"):
#
# ...
