# %%
import sys
sys.path.append("../../..")

from src.adapters.cameras import MockCamera
from src.app.configs.cameras import MockCameraConfig

# %%
config = MockCameraConfig(
    width=640,
    height=320,
    fps=144,
)

# %%
camera = MockCamera(config)
camera.get_actual_properties()
# Out:
# (640, 320, 144)

# %%
camera.read()
# Out:
# array([[[ 24,  59,  55],
#         [206,  20,   9],
#         [ 60, 191, 212],
#         ...,
#         [206, 140,  45],
#         [226, 180, 181],
#         [ 89, 124,  99]],
#
#        [[227,  14,  93],
#         [165, 194, 217],
#         [202, 117, 127],
#         ...,
#         [254, 174,  64],
#         [195, 230, 100],
#         [252, 188,  23]],
#
#        [[ 16, 192,  80],
#         [  0,  36, 227],
#         [234, 223,  53],
#         ...,
#         [187,  35, 205],
#         [ 65, 195, 138],
#         [131,  32,   0]],
#
#        ...,
#
#        [[216, 241, 107],
#         [ 14,  99,  28],
#         [196,  34,  12],
#         ...,
#         [ 44,  89, 249],
#         [184, 194,  97],
#         [198,   2, 103]],
#
#        [[209, 155, 134],
#         [209,  90,  60],
#         [177, 252, 110],
#         ...,
#         [ 82, 145, 208],
#         [ 30, 211,  79],
#         [ 44, 103, 233]],
#
#        [[ 34, 235, 101],
#         [138,  14,  54],
#         [ 74,  76,  41],
#         ...,
#         [204, 137, 116],
#         [ 16, 206,  79],
#         [ 71, 184, 233]]], shape=(320, 640, 3), dtype=uint8)
