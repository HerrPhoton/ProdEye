# %%
import sys
sys.path.append("../../../..")

from src.adapters.checkout import UICheckoutInput
from src.core.dto import CheckoutRequest
from src.app.parsers import parse_checkout_input

# %%
request = CheckoutRequest(
    label="apple"
)

# %%
config = {
    "type": "ui",
}
config_object = parse_checkout_input(config)

# %%
checkout_input = UICheckoutInput(config_object)
checkout_input.put(request)
checkout_input.get_request()
# Out:
# CheckoutRequest(label='apple')
