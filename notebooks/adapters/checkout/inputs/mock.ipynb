# %%
import sys
sys.path.append("../../../..")

from src.adapters.checkout import MockCheckoutInput
from src.app.parsers import parse_checkout_input

# %%
config = {
    "type": "mock",
    "requests": [
        {
            "sku": "0001",
            "label": "apple",
        },
        {
            "sku": "0002",
            "label": "banana",
        },
        {
            "sku": "0003",
            "label": "orange",
        },
    ],
}
config_object = parse_checkout_input(config)

# %%
checkout_input = MockCheckoutInput(config_object)
checkout_input.get_request()
# Out:
# {'sku': '0001', 'label': 'apple'}
