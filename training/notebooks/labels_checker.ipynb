# %%
import sys
sys.path.append('..')

from processing.labels_checker import YOLOLabelsChecker

# %%
checker = YOLOLabelsChecker(labels_dir='../../dataset/raw/Tomato/train/labels',
                            fix_classes=True,
                            remove_invalid=True,
                            verbose=True)
checker.process_labels()
# Out:
# Обработка меток:   6%|▌         | 28/500 [00:00<00:01, 280.00it/s]
# IMG20240511111544_jpg.rf.61cd102300926a42fcef1d6203e30c75.txt: Номер класса не равен 0
# IMG20240511111544_jpg.rf.72b9e9721f4ff2a1f9ed99bd5d3eda45.txt: Номер класса не равен 0
# IMG20240511111544_jpg.rf.9d27334f65a2e57f110f1cb308932f1c.txt: Номер класса не равен 0
# IMG20240511111623_jpg.rf.95d260a6e3f9dd20d703ca73285809f8.txt: Номер класса не равен 0
# IMG20240511111623_jpg.rf.c56cbc8e1b0a8ff5cf111be8f1d616dd.txt: Номер класса не равен 0
# IMG20240511111637_jpg.rf.4d28e8961d75094e66e1b1f3b7b3a293.txt: Номер класса не равен 0
# IMG20240511111637_jpg.rf.696de286427500b90a5e30cca915514d.txt: Номер класса не равен 0
# IMG20240511111637_jpg.rf.93b1f5769182bf3cbb534111f2f5f961.txt: Номер класса не равен 0
# IMG20240511111658_jpg.rf.624a3bcfed967c0a0e4820a8ed70e4bf.txt: Номер класса не равен 0
# IMG20240511111658_jpg.rf.e2dd65af5ad04474e653a0c33e9fe277.txt: Номер класса не равен 0
# ...
